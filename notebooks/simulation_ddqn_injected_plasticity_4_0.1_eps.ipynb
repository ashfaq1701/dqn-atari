# %%
import numpy as np

from src.main import train_dqn
from src.visualization import plot_rewards, plot_q, plot_all_rewards

# %%
beamrider_rewards, beamrider_max_steps, beamrider_q_values, beamrider_losses, beamrider_model = train_dqn(
    "ALE/BeamRider-v5", 
    method="ddqn_injected_plasticity",
    plasticity_training_epsilon=0.1
)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 2024-04-16 20:13:26.838312: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-04-16 20:13:26.838345: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-04-16 20:13:26.838349: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-04-16 20:13:26.838370: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-16 20:13:26.838381: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
plot_rewards(beamrider_rewards, title='Beam Rider Rewards Over Episodes')

# %%
plot_q(beamrider_q_values, title='Beam Rider Q Values Over Episodes')

# %%
np.save("../data/save/beamrider_rewards_ddqn_injected_plasticity_0-1_eps.npy", np.array(beamrider_rewards))
np.save("../data/save/beamrider_max_steps_ddqn_injected_plasticity_0-1_eps.npy", np.array(beamrider_max_steps))
np.save("../data/save/beamrider_q_values_ddqn_injected_plasticity_0-1_eps.npy", np.array(beamrider_q_values))
np.save("../data/save/beamrider_losses_ddqn_injected_plasticity_0-1_eps.npy", np.array(beamrider_losses))

# %%
beamrider_model.save("../data/saved_models/beamrider_model_ddqn_injected_plasticity_0-1_eps.keras")
