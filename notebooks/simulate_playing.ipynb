# %%
from src.visualization.play import simulate_playing_game

# %%
import keras

keras.config.enable_unsafe_deserialization()

# %%
anim_spaceinvaders_dqn, total_rewards_spaceinvaders_dqn = simulate_playing_game("../data/saved_models/spaceinvaders_model_dqn.keras", env_name="ALE/SpaceInvaders-v5")
# Out:
# 2024-04-09 13:56:15.638255: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 anim_spaceinvaders_dqn, total_rewards_spaceinvaders_dqn = simulate_playing_game("../data/saved_models/spaceinvaders_model_dqn.keras", env_name="ALE/SpaceInvaders-v5")
#
# File ~/PycharmProjects/rl-atari/src/visualization/play.py:42, in simulate_playing_game(model_path, env_name, env_seed, history_len, max_steps, frame_shape)
#      39     if done or truncated:
#      40         break
# ---> 42 anim = plot_animation(frames)
#      43 return anim, total_rewards
#
# File ~/PycharmProjects/rl-atari/src/visualization/play.py:55, in plot_animation(frames, repeat, interval)
#      53 patch = plt.imshow(frames[0])
#      54 plt.axis('off')
# ...
