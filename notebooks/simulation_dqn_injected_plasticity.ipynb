# %%
import numpy as np

from src.main import train_dqn
from src.visualization import plot_rewards, plot_q, plot_all_rewards

# %%
spaceinvaders_rewards, spaceinvaders_max_steps, spaceinvaders_q_values, spaceinvaders_model = train_dqn("ALE/SpaceInvaders-v5", method="dqn_injected_plasticity", n_episodes=100)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 2024-04-04 22:03:19.084856: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-04-04 22:03:19.084874: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-04-04 22:03:19.084877: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-04-04 22:03:19.084892: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-04 22:03:19.084902: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/ashfaq/.local/share/virtualenvs/rl-atari-7yjpj432/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Episode: 1, Steps: 609, eps: 1.000, total rewards: 210.0
# 2024-04-04 22:03:19.506820: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# Episode: 2, Steps: 773, eps: 0.975, total rewards: 295.0
# Episode: 3, Steps: 427, eps: 0.950, total rewards: 180.0
# Episode: 4, Steps: 524, eps: 0.925, total rewards: 110.0
# Episode: 5, Steps: 1200, eps: 0.900, total rewards: 550.0
# Episode: 6, Steps: 584, eps: 0.875, total rewards: 180.0
# Episode: 7, Steps: 418, eps: 0.850, total rewards: 105.0
# Episode: 8, Steps: 666, eps: 0.825, total rewards: 195.0
# Episode: 9, Steps: 559, eps: 0.800, total rewards: 135.0
# Episode: 10, Steps: 601, eps: 0.775, total rewards: 150.0
# Episode: 11, Steps: 493, eps: 0.750, total rewards: 135.0
# Episode: 12, Steps: 519, eps: 0.725, total rewards: 110.0
# Episode: 13, Steps: 574, eps: 0.700, total rewards: 135.0
# Episode: 14, Steps: 619, eps: 0.675, total rewards: 155.0
# Episode: 15, Steps: 645, eps: 0.650, total rewards: 210.0
# Episode: 16, Steps: 589, eps: 0.625, total rewards: 120.0
# Episode: 17, Steps: 585, eps: 0.600, total rewards: 135.0
# Episode: 18, Steps: 588, eps: 0.575, total rewards: 180.0
# Episode: 19, Steps: 644, eps: 0.550, total rewards: 410.0
# Episode: 20, Steps: 998, eps: 0.525, total rewards: 745.0
# Episode: 21, Steps: 624, eps: 0.500, total rewards: 160.0
# Episode: 22, Steps: 641, eps: 0.475, total rewards: 180.0
# Episode: 23, Steps: 602, eps: 0.450, total rewards: 120.0
# Episode: 24, Steps: 634, eps: 0.425, total rewards: 155.0
# Episode: 25, Steps: 806, eps: 0.400, total rewards: 235.0
# Episode: 26, Steps: 566, eps: 0.375, total rewards: 105.0
# Episode: 27, Steps: 640, eps: 0.350, total rewards: 165.0
# Episode: 28, Steps: 657, eps: 0.325, total rewards: 180.0
# Episode: 29, Steps: 645, eps: 0.300, total rewards: 150.0
# Episode: 30, Steps: 765, eps: 0.275, total rewards: 155.0
# Episode: 31, Steps: 1353, eps: 0.250, total rewards: 315.0
# Episode: 32, Steps: 619, eps: 0.225, total rewards: 180.0
# Episode: 33, Steps: 615, eps: 0.200, total rewards: 135.0
# Episode: 34, Steps: 637, eps: 0.175, total rewards: 210.0
# Episode: 35, Steps: 621, eps: 0.150, total rewards: 335.0
# Episode: 36, Steps: 630, eps: 0.125, total rewards: 210.0
# Episode: 37, Steps: 645, eps: 0.100, total rewards: 155.0
# Episode: 38, Steps: 609, eps: 0.075, total rewards: 135.0
# Episode: 39, Steps: 639, eps: 0.050, total rewards: 155.0
# Episode: 40, Steps: 614, eps: 0.025, total rewards: 135.0
# Episode: 41, Steps: 813, eps: 0.010, total rewards: 215.0
# Episode: 42, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 43, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 44, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 45, Steps: 1421, eps: 0.010, total rewards: 460.0
# Episode: 46, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 47, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 48, Steps: 615, eps: 0.010, total rewards: 135.0
# Episode: 49, Steps: 651, eps: 0.010, total rewards: 155.0
# Episode: 50, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 1, Steps: 473, eps: 1.000, total rewards: 120.0
# Episode: 2, Steps: 311, eps: 0.950, total rewards: 80.0
# Episode: 3, Steps: 817, eps: 0.900, total rewards: 215.0
# Episode: 4, Steps: 379, eps: 0.850, total rewards: 50.0
# Episode: 5, Steps: 305, eps: 0.800, total rewards: 30.0
# Episode: 6, Steps: 601, eps: 0.750, total rewards: 180.0
# Episode: 7, Steps: 678, eps: 0.700, total rewards: 175.0
# Episode: 8, Steps: 336, eps: 0.650, total rewards: 20.0
# Episode: 9, Steps: 316, eps: 0.600, total rewards: 75.0
# Episode: 10, Steps: 624, eps: 0.550, total rewards: 125.0
# Episode: 11, Steps: 589, eps: 0.500, total rewards: 120.0
# Episode: 12, Steps: 634, eps: 0.450, total rewards: 180.0
# Episode: 13, Steps: 588, eps: 0.400, total rewards: 335.0
# Episode: 14, Steps: 619, eps: 0.350, total rewards: 180.0
# Episode: 15, Steps: 487, eps: 0.300, total rewards: 110.0
# Episode: 16, Steps: 625, eps: 0.250, total rewards: 155.0
# Episode: 17, Steps: 637, eps: 0.200, total rewards: 180.0
# Episode: 18, Steps: 603, eps: 0.150, total rewards: 120.0
# Episode: 19, Steps: 618, eps: 0.100, total rewards: 155.0
# Episode: 20, Steps: 609, eps: 0.050, total rewards: 135.0
# Episode: 21, Steps: 646, eps: 0.010, total rewards: 155.0
# Episode: 22, Steps: 831, eps: 0.010, total rewards: 210.0
# Episode: 23, Steps: 624, eps: 0.010, total rewards: 155.0
# Episode: 24, Steps: 645, eps: 0.010, total rewards: 155.0
# Episode: 25, Steps: 645, eps: 0.010, total rewards: 155.0

# %%
plot_rewards(spaceinvaders_rewards, title='SpaceInvaders Rewards Over Episodes')

# %%
plot_q(spaceinvaders_q_values, title='SpaceInvaders Q Values Over Episodes')

# %%
np.save("../data/save/spaceinvaders_rewards_dqn_injected_plasticity.npy", np.array(spaceinvaders_rewards))
np.save("../data/save/spaceinvaders_max_steps_dqn_injected_plasticity.npy", np.array(spaceinvaders_max_steps))
np.save("../data/save/spaceinvaders_q_values_dqn_injected_plasticity.npy", np.array(spaceinvaders_q_values))

# %%
spaceinvaders_model.save("../data/saved_models/spaceinvaders_model_dqn_injected_plasticity.keras")

# %%
breakout_rewards, breakout_max_steps, breakout_q_values, breakout_model = train_dqn("ALE/Breakout-v5", method="dqn_injected_plasticity")

# %%
plot_rewards(breakout_rewards, title='Breakout Rewards Over Episodes')

# %%
plot_q(breakout_q_values, title='Breakout Q Values Over Episodes')

# %%
np.save("../data/save/breakout_rewards_dqn_injected_plasticity.npy", np.array(breakout_rewards))
np.save("../data/save/breakout_max_steps_dqn_injected_plasticity.npy", np.array(breakout_max_steps))
np.save("../data/save/breakout_q_values_dqn_injected_plasticity.npy", np.array(breakout_q_values))

# %%
breakout_model.save("../saved_models/breakout_model_dqn_injected_plasticity.keras")

# %%
seaquest_rewards, seaquest_max_steps, seaquest_q_values, seaquest_model = train_dqn("ALE/Seaquest-v5", method="dqn_injected_plasticity")

# %%
plot_rewards(seaquest_rewards, title='SeaQuest Rewards Over Episodes')

# %%
plot_q(seaquest_rewards, title='SeaQuest Q Values Over Episodes')

# %%
np.save("../data/save/seaquest_rewards_dqn_injected_plasticity.npy", np.array(seaquest_rewards))
np.save("../data/save/seaquest_max_steps_dqn_injected_plasticity.npy", np.array(seaquest_max_steps))
np.save("../data/save/seaquest_q_values_dqn_injected_plasticity.npy", np.array(seaquest_q_values))

# %%
seaquest_model.save("../saved_models/seaquest_model_dqn_injected_plasticity.keras")

# %%
pong_rewards, pong_max_steps, pong_q_values, pong_model = train_dqn("ALE/Pong-v5", method="dqn_injected_plasticity")

# %%
plot_rewards(pong_rewards, title='Pong Rewards Over Episodes')

# %%
plot_q(pong_rewards, title='Pong Q Values Over Episodes')

# %%
np.save("../data/save/pong_rewards_dqn_injected_plasticity.npy", np.array(pong_rewards))
np.save("../data/save/pong_max_steps_dqn_injected_plasticity.npy", np.array(pong_max_steps))
np.save("../data/save/pong_q_values_dqn_injected_plasticity.npy", np.array(pong_q_values))

# %%
pong_model.save("../saved_models/pong_model_dqn_injected_plasticity.keras")

# %%
plot_all_rewards(spaceinvaders_rewards, breakout_rewards, pong_rewards, seaquest_rewards, "DQN with Plasticity")
