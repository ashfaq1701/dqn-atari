# %%
import numpy as np
from src.main import train_dqn
from src.visualization import plot_rewards, plot_q, plot_all_rewards

# %%
spaceinvaders_rewards, spaceinvaders_max_steps, spaceinvaders_q_values, spaceinvaders_losses, spaceinvaders_model = train_dqn(
    "ALE/SpaceInvaders-v5", 
    method="ddqn_injected_plasticity",
    plasticity_training_epsilon=0.1
)
# Out:
# /Users/ashfaq/.local/share/virtualenvs/rl-atari-7yjpj432/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Episode: 1, Steps: 341, eps: 1.000, total rewards: 100.0
# Episode: 2, Steps: 297, eps: 1.000, total rewards: 30.0
# Episode: 3, Steps: 445, eps: 1.000, total rewards: 155.0
# Episode: 4, Steps: 403, eps: 1.000, total rewards: 60.0
# Episode: 5, Steps: 395, eps: 0.999, total rewards: 60.0
# Episode: 6, Steps: 529, eps: 0.999, total rewards: 105.0
# Episode: 7, Steps: 538, eps: 0.999, total rewards: 210.0
# Episode: 8, Steps: 945, eps: 0.999, total rewards: 410.0
# Episode: 9, Steps: 452, eps: 0.999, total rewards: 110.0
# Episode: 10, Steps: 452, eps: 0.999, total rewards: 125.0
# Episode: 11, Steps: 530, eps: 0.999, total rewards: 165.0
# ...

# %%
plot_rewards(spaceinvaders_rewards, title='SpaceInvaders Rewards Over Episodes')

# %%
max(spaceinvaders_rewards)
# Out:
# 965.0

# %%
plot_q(spaceinvaders_q_values, title='SpaceInvaders Q Values Over Episodes')

# %%
np.save("../data/save/spaceinvaders_rewards_ddqn_injected_plasticity_0-1_eps.npy", np.array(spaceinvaders_rewards))
np.save("../data/save/spaceinvaders_max_steps_ddqn_injected_plasticity_0-1_eps.npy", np.array(spaceinvaders_max_steps))
np.save("../data/save/spaceinvaders_q_values_ddqn_injected_plasticity_0-1_eps.npy", np.array(spaceinvaders_q_values))
np.save("../data/save/spaceinvaders_losses_ddqn_injected_plasticity_0-1_eps", np.array(spaceinvaders_losses))

# %%
spaceinvaders_model.save("../data/saved_models/spaceinvaders_model_ddqn_injected_plasticity_0-1_eps.keras")
