# %%
import numpy as np

from src.main import train_dqn
from src.visualization import plot_rewards, plot_q, plot_all_rewards

# %%
breakout_rewards, breakout_max_steps, breakout_q_values, breakout_losses, breakout_model = train_dqn(
    "ALE/Breakout-v5", 
    method="ddqn_injected_plasticity",
    plasticity_training_epsilon=0.1
)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 2024-04-23 18:26:13.871361: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-04-23 18:26:13.871385: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-04-23 18:26:13.871388: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-04-23 18:26:13.871404: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-23 18:26:13.871414: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
plot_rewards(breakout_losses, title="Losses")

# %%
plot_rewards(breakout_rewards, title='Breakout Rewards Over Episodes')

# %%
max(breakout_rewards)
# Out:
# 15.0

# %%
plot_q(breakout_q_values, title='Breakout Q Values Over Episodes')

# %%
np.save("../data/save/breakout_rewards_ddqn_injected_plasticity_0-1_eps.npy", np.array(breakout_rewards))
np.save("../data/save/breakout_max_steps_ddqn_injected_plasticity_0-1_eps.npy", np.array(breakout_max_steps))
np.save("../data/save/breakout_q_values_ddqn_injected_plasticity_0-1_eps.npy", np.array(breakout_q_values))
np.save("../data/save/breakout_losses_ddqn_injected_plasticity_0-1_eps.npy", np.array(breakout_losses))

# %%
breakout_model.save("../data/saved_models/breakout_model_ddqn_injected_plasticity_0-1_eps.keras")
