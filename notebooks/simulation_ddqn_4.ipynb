# %%
import numpy as np
from src.main import train_dqn
from src.visualization import plot_rewards, plot_q, plot_all_rewards

# %%
qbert_rewards, qbert_max_steps, qbert_q_values, qbert_losses, qbert_model = train_dqn("ALE/Qbert-v5", method="ddqn")
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 2024-04-23 18:26:08.660720: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-04-23 18:26:08.660738: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-04-23 18:26:08.660741: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-04-23 18:26:08.660756: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-23 18:26:08.660765: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Episode: 1, Steps: 329, eps: 1.000, total rewards: 100.0
# ...

# %%
plot_rewards(qbert_losses, title="Losses")

# %%
plot_rewards(qbert_rewards, title='Qbert Rewards Over Episodes')

# %%
max(qbert_rewards)
# Out:
# 1325.0

# %%
plot_q(qbert_q_values, title='Qbert Q Values Over Episodes')

# %%
np.save("../data/save/qbert_rewards_ddqn.npy", np.array(qbert_rewards))
np.save("../data/save/qbert_max_steps_ddqn.npy", np.array(qbert_max_steps))
np.save("../data/save/qbert_q_values_ddqn.npy", np.array(qbert_q_values))
np.save("../data/save/qbert_losses_ddqn.npy", np.array(qbert_losses))

# %%
qbert_model.save("../data/saved_models/qbert_model_ddqn.keras")
